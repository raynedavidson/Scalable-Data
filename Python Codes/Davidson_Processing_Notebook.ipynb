# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Functions used below

def username():
    """Get username with any domain information removed.
    """

    return re.sub('@.*', '', getpass.getuser())


def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

    
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'<li><a href="{sc.uiWebUrl}" target="_blank">Spark Application UI</a></li>',
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username() + " (jupyter)"}</code> is under the completed applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    user = username()
    
    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .master("spark://masternode2:7077")
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{user}/spark/")
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.executor.memory", f"{worker_memory}g")
        .config("spark.driver.memory", f"{master_memory}g")
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.ui.port", str(port))
        .appName(user + " (jupyter)")
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()

    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        spark.stop()

        del spark
        del sc

    display_spark()


# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))


# Print function docstrings

help(start_spark)
help(stop_spark)
help(display_spark)
help(show_as_html)
# Out:
# <style>pre { white-space: pre !important; }table.dataframe td { white-space: nowrap !important; }table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }</style>
# Help on function start_spark in module __main__:
#
# start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1)
#     Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
#
#     Args:
#         executor_instances (int): number of executors (default: 2)
#         executor_cores (int): number of cores per executor (default: 1)
#         worker_memory (float): worker memory (default: 1)
#         master_memory (float): master memory (default: 1)
#
# Help on function stop_spark in module __main__:
#
# stop_spark()
#     Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
#
# Help on function display_spark in module __main__:
#
# display_spark()
#     Display the status of the active Spark session if one is currently running.
#
# Help on function show_as_html in module __main__:
#
# show_as_html(df, n=20)
#     Leverage existing pandas jupyter integration to show a spark dataframe as html.
#
#     Args:
#         n (int): number of rows to show (default: 20)

# %%
# Run this cell to start a spark session in this notebook

start_spark(executor_instances=4, executor_cores=2, worker_memory=4, master_memory=4)
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:green">active</span></b>, look for <code>mda205 (jupyter)</code> under the running applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li><li><a href="http://mathmadslinux2p.canterbury.ac.nz:4582" target="_blank">Spark Application UI</a></li></ul><p><b>Config</b></p><table width="100%" style="width:100%; font-family: monospace;"><tr><td style="text-align:left;">spark.dynamicAllocation.enabled</td><td>false</td></tr><tr><td style="text-align:left;">spark.executor.instances</td><td>4</td></tr><tr><td style="text-align:left;">spark.driver.memory</td><td>4g</td></tr><tr><td style="text-align:left;">spark.executor.memory</td><td>4g</td></tr><tr><td style="text-align:left;">spark.master</td><td>spark://masternode2:7077</td></tr><tr><td style="text-align:left;">spark.executor.id</td><td>driver</td></tr><tr><td style="text-align:left;">spark.sql.warehouse.dir</td><td>file:/users/home/mda205/spark-warehouse</td></tr><tr><td style="text-align:left;">spark.executor.cores</td><td>2</td></tr><tr><td style="text-align:left;">spark.driver.host</td><td>mathmadslinux2p.canterbury.ac.nz</td></tr><tr><td style="text-align:left;">spark.sql.shuffle.partitions</td><td>32</td></tr><tr><td style="text-align:left;">spark.driver.extraJavaOptions</td><td>-Dderby.system.home=/tmp/mda205/spark/</td></tr><tr><td style="text-align:left;">spark.driver.port</td><td>41843</td></tr><tr><td style="text-align:left;">spark.app.name</td><td>mda205 (jupyter)</td></tr><tr><td style="text-align:left;">spark.rdd.compress</td><td>True</td></tr><tr><td style="text-align:left;">spark.ui.port</td><td>4582</td></tr><tr><td style="text-align:left;">spark.serializer.objectStreamReset</td><td>100</td></tr><tr><td style="text-align:left;">spark.driver.maxResultSize</td><td>0</td></tr><tr><td style="text-align:left;">spark.cores.max</td><td>8</td></tr><tr><td style="text-align:left;">spark.submit.pyFiles</td><td></td></tr><tr><td style="text-align:left;">spark.submit.deployMode</td><td>client</td></tr><tr><td style="text-align:left;">spark.app.startTime</td><td>1682649860229</td></tr><tr><td style="text-align:left;">spark.app.id</td><td>app-20230428144421-0108</td></tr><tr><td style="text-align:left;">spark.ui.showConsoleProgress</td><td>true</td></tr></table><p><b>Notes</b></p><ul><li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li><li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>mda205 (jupyter)</code> by hand using the link in the Spark UI.</li></ul>

# %%
# Write your imports and code here or insert cells below

from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.window import Window
import textwrap
import glob

# %% [markdown]
# ## Processing Q1

# %%
# !hdfs dfs -ls -h hdfs:///data/ghcnd #next 4 for Q1
# Out:
# Found 6 items
# drwxr-xr-x   - jsw93 supergroup          0 2023-03-13 15:09 hdfs:///data/ghcnd/daily
# drwxr-xr-x   - jsw93 supergroup          0 2023-04-19 19:33 hdfs:///data/ghcnd/daily-uncompressed
# -rw-r--r--   8 jsw93 supergroup      3.6 K 2023-03-13 14:52 hdfs:///data/ghcnd/ghcnd-countries.txt
# -rw-r--r--   8 jsw93 supergroup     32.4 M 2023-03-13 14:52 hdfs:///data/ghcnd/ghcnd-inventory.txt
# -rw-r--r--   8 jsw93 supergroup      1.1 K 2023-03-13 14:52 hdfs:///data/ghcnd/ghcnd-states.txt
# -rw-r--r--   8 jsw93 supergroup     10.2 M 2023-03-13 14:52 hdfs:///data/ghcnd/ghcnd-stations.txt

# %%
# !hdfs dfs -du -s -h hdfs:///data/ghcnd/daily
# Out:
# 12.2 G  97.6 G  hdfs:///data/ghcnd/daily

# %%
# !hdfs dfs -ls -h hdfs:///data/ghcnd/daily |wc -l
# Out:
# 263

# %%
# !hdfs dfs -ls -h hdfs:///data/ghcnd/daily
# Out:
# Found 262 items
# -rw-r--r--   8 jsw93 supergroup     63.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1750.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1763.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1764.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1765.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1766.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1767.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1768.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1769.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1770.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1771.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1772.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1773.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1774.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1775.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1776.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1777.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1778.csv.gz
# -rw-r--r--   8 jsw93 supergroup        6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1779.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1780.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1781.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1782.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1783.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1784.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1785.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1786.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1787.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1788.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1789.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1790.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1791.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1792.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1793.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1794.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1795.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1796.csv.gz
# -rw-r--r--   8 jsw93 supergroup      9.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1797.csv.gz
# -rw-r--r--   8 jsw93 supergroup      9.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1798.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1799.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1800.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1801.csv.gz
# -rw-r--r--   8 jsw93 supergroup      9.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1802.csv.gz
# -rw-r--r--   8 jsw93 supergroup      7.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1803.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1804.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1805.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1806.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1807.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1808.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1809.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1810.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1811.csv.gz
# -rw-r--r--   8 jsw93 supergroup      8.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1812.csv.gz
# -rw-r--r--   8 jsw93 supergroup      9.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1813.csv.gz
# -rw-r--r--   8 jsw93 supergroup     10.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1814.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1815.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1816.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1817.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1818.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1819.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1820.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1821.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1822.csv.gz
# -rw-r--r--   8 jsw93 supergroup     14.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1823.csv.gz
# -rw-r--r--   8 jsw93 supergroup     17.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1824.csv.gz
# -rw-r--r--   8 jsw93 supergroup     17.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1825.csv.gz
# -rw-r--r--   8 jsw93 supergroup     18.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1826.csv.gz
# -rw-r--r--   8 jsw93 supergroup     20.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1827.csv.gz
# -rw-r--r--   8 jsw93 supergroup     20.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1828.csv.gz
# -rw-r--r--   8 jsw93 supergroup     20.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1829.csv.gz
# -rw-r--r--   8 jsw93 supergroup     20.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1830.csv.gz
# -rw-r--r--   8 jsw93 supergroup     20.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1831.csv.gz
# -rw-r--r--   8 jsw93 supergroup     21.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1832.csv.gz
# -rw-r--r--   8 jsw93 supergroup     26.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1833.csv.gz
# -rw-r--r--   8 jsw93 supergroup     26.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1834.csv.gz
# -rw-r--r--   8 jsw93 supergroup     26.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1835.csv.gz
# -rw-r--r--   8 jsw93 supergroup     29.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1836.csv.gz
# -rw-r--r--   8 jsw93 supergroup     28.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1837.csv.gz
# -rw-r--r--   8 jsw93 supergroup     31.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1838.csv.gz
# -rw-r--r--   8 jsw93 supergroup     28.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1839.csv.gz
# -rw-r--r--   8 jsw93 supergroup     35.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1840.csv.gz
# -rw-r--r--   8 jsw93 supergroup     36.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1841.csv.gz
# -rw-r--r--   8 jsw93 supergroup     38.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1842.csv.gz
# -rw-r--r--   8 jsw93 supergroup     38.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1843.csv.gz
# -rw-r--r--   8 jsw93 supergroup     42.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1844.csv.gz
# -rw-r--r--   8 jsw93 supergroup     46.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1845.csv.gz
# -rw-r--r--   8 jsw93 supergroup     43.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1846.csv.gz
# -rw-r--r--   8 jsw93 supergroup     45.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1847.csv.gz
# -rw-r--r--   8 jsw93 supergroup     44.0 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1848.csv.gz
# -rw-r--r--   8 jsw93 supergroup     46.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1849.csv.gz
# -rw-r--r--   8 jsw93 supergroup     46.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1850.csv.gz
# -rw-r--r--   8 jsw93 supergroup     53.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1851.csv.gz
# -rw-r--r--   8 jsw93 supergroup     57.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1852.csv.gz
# -rw-r--r--   8 jsw93 supergroup     58.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1853.csv.gz
# -rw-r--r--   8 jsw93 supergroup     57.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1854.csv.gz
# -rw-r--r--   8 jsw93 supergroup     63.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1855.csv.gz
# -rw-r--r--   8 jsw93 supergroup     74.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1856.csv.gz
# -rw-r--r--   8 jsw93 supergroup     81.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1857.csv.gz
# -rw-r--r--   8 jsw93 supergroup    112.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1858.csv.gz
# -rw-r--r--   8 jsw93 supergroup    125.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1859.csv.gz
# -rw-r--r--   8 jsw93 supergroup    134.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1860.csv.gz
# -rw-r--r--   8 jsw93 supergroup    139.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1861.csv.gz
# -rw-r--r--   8 jsw93 supergroup    134.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1862.csv.gz
# -rw-r--r--   8 jsw93 supergroup    151.3 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1863.csv.gz
# -rw-r--r--   8 jsw93 supergroup    155.7 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1864.csv.gz
# -rw-r--r--   8 jsw93 supergroup    156.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1865.csv.gz
# -rw-r--r--   8 jsw93 supergroup    203.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1866.csv.gz
# -rw-r--r--   8 jsw93 supergroup    243.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1867.csv.gz
# -rw-r--r--   8 jsw93 supergroup    255.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1868.csv.gz
# -rw-r--r--   8 jsw93 supergroup    296.1 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1869.csv.gz
# -rw-r--r--   8 jsw93 supergroup    339.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1870.csv.gz
# -rw-r--r--   8 jsw93 supergroup    446.4 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1871.csv.gz
# -rw-r--r--   8 jsw93 supergroup    605.5 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1872.csv.gz
# -rw-r--r--   8 jsw93 supergroup    677.8 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1873.csv.gz
# -rw-r--r--   8 jsw93 supergroup    757.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1874.csv.gz
# -rw-r--r--   8 jsw93 supergroup    821.9 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1875.csv.gz
# -rw-r--r--   8 jsw93 supergroup    891.2 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1876.csv.gz
# -rw-r--r--   8 jsw93 supergroup    993.6 K 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1877.csv.gz
# -rw-r--r--   8 jsw93 supergroup      1.2 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1878.csv.gz
# -rw-r--r--   8 jsw93 supergroup      1.3 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1879.csv.gz
# -rw-r--r--   8 jsw93 supergroup      1.7 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1880.csv.gz
# -rw-r--r--   8 jsw93 supergroup      2.0 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1881.csv.gz
# -rw-r--r--   8 jsw93 supergroup      2.3 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1882.csv.gz
# -rw-r--r--   8 jsw93 supergroup      2.5 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1883.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.0 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1884.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.4 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1885.csv.gz
# -rw-r--r--   8 jsw93 supergroup      3.7 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1886.csv.gz
# -rw-r--r--   8 jsw93 supergroup      4.2 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1887.csv.gz
# -rw-r--r--   8 jsw93 supergroup      4.5 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1888.csv.gz
# -rw-r--r--   8 jsw93 supergroup      4.9 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1889.csv.gz
# -rw-r--r--   8 jsw93 supergroup      5.3 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1890.csv.gz
# -rw-r--r--   8 jsw93 supergroup      5.6 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1891.csv.gz
# -rw-r--r--   8 jsw93 supergroup      6.5 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1892.csv.gz
# -rw-r--r--   8 jsw93 supergroup     11.9 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1893.csv.gz
# -rw-r--r--   8 jsw93 supergroup     12.8 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1894.csv.gz
# -rw-r--r--   8 jsw93 supergroup     13.8 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1895.csv.gz
# -rw-r--r--   8 jsw93 supergroup     14.9 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1896.csv.gz
# -rw-r--r--   8 jsw93 supergroup     16.0 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1897.csv.gz
# -rw-r--r--   8 jsw93 supergroup     16.7 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1898.csv.gz
# -rw-r--r--   8 jsw93 supergroup     17.4 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1899.csv.gz
# -rw-r--r--   8 jsw93 supergroup     18.6 M 2023-03-13 14:59 hdfs:///data/ghcnd/daily/1900.csv.gz
# -rw-r--r--   8 jsw93 supergroup     23.6 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1901.csv.gz
# -rw-r--r--   8 jsw93 supergroup     24.5 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1902.csv.gz
# -rw-r--r--   8 jsw93 supergroup     25.0 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1903.csv.gz
# -rw-r--r--   8 jsw93 supergroup     25.9 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1904.csv.gz
# -rw-r--r--   8 jsw93 supergroup     27.2 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1905.csv.gz
# -rw-r--r--   8 jsw93 supergroup     27.8 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1906.csv.gz
# -rw-r--r--   8 jsw93 supergroup     28.5 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1907.csv.gz
# -rw-r--r--   8 jsw93 supergroup     29.2 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1908.csv.gz
# -rw-r--r--   8 jsw93 supergroup     30.7 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1909.csv.gz
# -rw-r--r--   8 jsw93 supergroup     31.7 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1910.csv.gz
# -rw-r--r--   8 jsw93 supergroup     32.9 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1911.csv.gz
# -rw-r--r--   8 jsw93 supergroup     34.1 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1912.csv.gz
# -rw-r--r--   8 jsw93 supergroup     35.0 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1913.csv.gz
# -rw-r--r--   8 jsw93 supergroup     36.2 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1914.csv.gz
# -rw-r--r--   8 jsw93 supergroup     37.3 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1915.csv.gz
# -rw-r--r--   8 jsw93 supergroup     38.6 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1916.csv.gz
# -rw-r--r--   8 jsw93 supergroup     38.8 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1917.csv.gz
# -rw-r--r--   8 jsw93 supergroup     37.9 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1918.csv.gz
# -rw-r--r--   8 jsw93 supergroup     37.4 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1919.csv.gz
# -rw-r--r--   8 jsw93 supergroup     37.7 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1920.csv.gz
# -rw-r--r--   8 jsw93 supergroup     37.9 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1921.csv.gz
# -rw-r--r--   8 jsw93 supergroup     38.6 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1922.csv.gz
# -rw-r--r--   8 jsw93 supergroup     39.3 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1923.csv.gz
# -rw-r--r--   8 jsw93 supergroup     40.1 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1924.csv.gz
# -rw-r--r--   8 jsw93 supergroup     40.3 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1925.csv.gz
# -rw-r--r--   8 jsw93 supergroup     41.5 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1926.csv.gz
# -rw-r--r--   8 jsw93 supergroup     42.2 M 2023-03-13 15:00 hdfs:///data/ghcnd/daily/1927.csv.gz
# -rw-r--r--   8 jsw93 supergroup     42.7 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1928.csv.gz
# -rw-r--r--   8 jsw93 supergroup     43.6 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1929.csv.gz
# -rw-r--r--   8 jsw93 supergroup     44.9 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1930.csv.gz
# -rw-r--r--   8 jsw93 supergroup     46.4 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1931.csv.gz
# -rw-r--r--   8 jsw93 supergroup     47.4 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1932.csv.gz
# -rw-r--r--   8 jsw93 supergroup     47.8 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1933.csv.gz
# -rw-r--r--   8 jsw93 supergroup     48.2 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1934.csv.gz
# -rw-r--r--   8 jsw93 supergroup     49.1 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1935.csv.gz
# -rw-r--r--   8 jsw93 supergroup     52.0 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1936.csv.gz
# -rw-r--r--   8 jsw93 supergroup     53.3 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1937.csv.gz
# -rw-r--r--   8 jsw93 supergroup     54.4 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1938.csv.gz
# -rw-r--r--   8 jsw93 supergroup     56.0 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1939.csv.gz
# -rw-r--r--   8 jsw93 supergroup     58.1 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1940.csv.gz
# -rw-r--r--   8 jsw93 supergroup     59.9 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1941.csv.gz
# -rw-r--r--   8 jsw93 supergroup     61.9 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1942.csv.gz
# -rw-r--r--   8 jsw93 supergroup     62.7 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1943.csv.gz
# -rw-r--r--   8 jsw93 supergroup     64.3 M 2023-03-13 15:01 hdfs:///data/ghcnd/daily/1944.csv.gz
# -rw-r--r--   8 jsw93 supergroup     66.6 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1945.csv.gz
# -rw-r--r--   8 jsw93 supergroup     67.0 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1946.csv.gz
# -rw-r--r--   8 jsw93 supergroup     68.6 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1947.csv.gz
# -rw-r--r--   8 jsw93 supergroup     81.8 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1948.csv.gz
# -rw-r--r--   8 jsw93 supergroup     93.7 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1949.csv.gz
# -rw-r--r--   8 jsw93 supergroup     96.5 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1950.csv.gz
# -rw-r--r--   8 jsw93 supergroup     99.5 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1951.csv.gz
# -rw-r--r--   8 jsw93 supergroup    100.8 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1952.csv.gz
# -rw-r--r--   8 jsw93 supergroup    102.2 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1953.csv.gz
# -rw-r--r--   8 jsw93 supergroup    104.1 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1954.csv.gz
# -rw-r--r--   8 jsw93 supergroup    106.3 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1955.csv.gz
# -rw-r--r--   8 jsw93 supergroup    108.4 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1956.csv.gz
# -rw-r--r--   8 jsw93 supergroup    110.9 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1957.csv.gz
# -rw-r--r--   8 jsw93 supergroup    111.9 M 2023-03-13 15:02 hdfs:///data/ghcnd/daily/1958.csv.gz
# -rw-r--r--   8 jsw93 supergroup    114.2 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1959.csv.gz
# -rw-r--r--   8 jsw93 supergroup    116.4 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1960.csv.gz
# -rw-r--r--   8 jsw93 supergroup    120.1 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1961.csv.gz
# -rw-r--r--   8 jsw93 supergroup    122.7 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1962.csv.gz
# -rw-r--r--   8 jsw93 supergroup    125.5 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1963.csv.gz
# -rw-r--r--   8 jsw93 supergroup    126.4 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1964.csv.gz
# -rw-r--r--   8 jsw93 supergroup    130.5 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1965.csv.gz
# -rw-r--r--   8 jsw93 supergroup    132.2 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1966.csv.gz
# -rw-r--r--   8 jsw93 supergroup    133.5 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1967.csv.gz
# -rw-r--r--   8 jsw93 supergroup    133.0 M 2023-03-13 15:03 hdfs:///data/ghcnd/daily/1968.csv.gz
# -rw-r--r--   8 jsw93 supergroup    134.7 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1969.csv.gz
# -rw-r--r--   8 jsw93 supergroup    135.6 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1970.csv.gz
# -rw-r--r--   8 jsw93 supergroup    130.6 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1971.csv.gz
# -rw-r--r--   8 jsw93 supergroup    129.7 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1972.csv.gz
# -rw-r--r--   8 jsw93 supergroup    135.8 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1973.csv.gz
# -rw-r--r--   8 jsw93 supergroup    137.0 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1974.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.5 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1975.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.3 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1976.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.1 M 2023-03-13 15:04 hdfs:///data/ghcnd/daily/1977.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.3 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1978.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.5 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1979.csv.gz
# -rw-r--r--   8 jsw93 supergroup    136.8 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1980.csv.gz
# -rw-r--r--   8 jsw93 supergroup    139.6 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1981.csv.gz
# -rw-r--r--   8 jsw93 supergroup    141.3 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1982.csv.gz
# -rw-r--r--   8 jsw93 supergroup    142.6 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1983.csv.gz
# -rw-r--r--   8 jsw93 supergroup    141.2 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1984.csv.gz
# -rw-r--r--   8 jsw93 supergroup    139.7 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1985.csv.gz
# -rw-r--r--   8 jsw93 supergroup    138.8 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1986.csv.gz
# -rw-r--r--   8 jsw93 supergroup    138.9 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1987.csv.gz
# -rw-r--r--   8 jsw93 supergroup    139.6 M 2023-03-13 15:05 hdfs:///data/ghcnd/daily/1988.csv.gz
# -rw-r--r--   8 jsw93 supergroup    140.0 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1989.csv.gz
# -rw-r--r--   8 jsw93 supergroup    140.2 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1990.csv.gz
# -rw-r--r--   8 jsw93 supergroup    140.8 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1991.csv.gz
# -rw-r--r--   8 jsw93 supergroup    141.0 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1992.csv.gz
# -rw-r--r--   8 jsw93 supergroup    139.9 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1993.csv.gz
# -rw-r--r--   8 jsw93 supergroup    138.9 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1994.csv.gz
# -rw-r--r--   8 jsw93 supergroup    138.6 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1995.csv.gz
# -rw-r--r--   8 jsw93 supergroup    138.8 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1996.csv.gz
# -rw-r--r--   8 jsw93 supergroup    137.7 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1997.csv.gz
# -rw-r--r--   8 jsw93 supergroup    140.8 M 2023-03-13 15:06 hdfs:///data/ghcnd/daily/1998.csv.gz
# -rw-r--r--   8 jsw93 supergroup    143.4 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/1999.csv.gz
# -rw-r--r--   8 jsw93 supergroup    145.3 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2000.csv.gz
# -rw-r--r--   8 jsw93 supergroup    147.6 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2001.csv.gz
# -rw-r--r--   8 jsw93 supergroup    149.0 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2002.csv.gz
# -rw-r--r--   8 jsw93 supergroup    152.4 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2003.csv.gz
# -rw-r--r--   8 jsw93 supergroup    154.5 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2004.csv.gz
# -rw-r--r--   8 jsw93 supergroup    151.5 M 2023-03-13 15:07 hdfs:///data/ghcnd/daily/2005.csv.gz
# -rw-r--r--   8 jsw93 supergroup    157.5 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2006.csv.gz
# -rw-r--r--   8 jsw93 supergroup    160.2 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2007.csv.gz
# -rw-r--r--   8 jsw93 supergroup    167.1 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2008.csv.gz
# -rw-r--r--   8 jsw93 supergroup    169.8 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2009.csv.gz
# -rw-r--r--   8 jsw93 supergroup    171.4 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2010.csv.gz
# -rw-r--r--   8 jsw93 supergroup    162.6 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2011.csv.gz
# -rw-r--r--   8 jsw93 supergroup    160.3 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2012.csv.gz
# -rw-r--r--   8 jsw93 supergroup    155.8 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2013.csv.gz
# -rw-r--r--   8 jsw93 supergroup    154.3 M 2023-03-13 15:08 hdfs:///data/ghcnd/daily/2014.csv.gz
# -rw-r--r--   8 jsw93 supergroup    156.7 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2015.csv.gz
# -rw-r--r--   8 jsw93 supergroup    158.1 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2016.csv.gz
# -rw-r--r--   8 jsw93 supergroup    157.7 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2017.csv.gz
# -rw-r--r--   8 jsw93 supergroup    157.8 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2018.csv.gz
# -rw-r--r--   8 jsw93 supergroup    156.6 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2019.csv.gz
# -rw-r--r--   8 jsw93 supergroup    157.4 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2020.csv.gz
# -rw-r--r--   8 jsw93 supergroup    155.3 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2021.csv.gz
# -rw-r--r--   8 jsw93 supergroup    158.4 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2022.csv.gz
# -rw-r--r--   8 jsw93 supergroup     26.2 M 2023-03-13 15:09 hdfs:///data/ghcnd/daily/2023.csv.gz

# %% [markdown]
# ## Processing Q2

# %% [markdown]
# Pr Q2 a

# %%
#Q2 a
schema_daily = StructType([
    StructField("Station_ID", StringType(), True),
    StructField("DATE", DateType(), True),
    StructField("Element", StringType(), True),
    StructField("Element_Value", IntegerType(), True),
    StructField("MEASUREMENT_FLAG", StringType(), True),
    StructField("QUALITY_FLAG", StringType(), True),
    StructField("SOURCE_FLAG", StringType(), True),
    StructField("OBSERVATION_TIME", StringType(), True),
])

# %% [markdown]
# Pr Q2 b

# %%
#Q2 b
dailyfirst1k=(
    spark.read.format("com.databricks.spark.csv")
    .option("header", "false")
    .option("inferSchema", "false")
    .option("dateFormat", "yyyymmdd")
    .schema(schema_daily).load("hdfs:///data/ghcnd/daily/2023.csv.gz").limit(1000))

dailyfirst1k.show(1000)
# Out:
# +-----------+----------+-------+-------------+----------------+------------+-----------+----------------+
# | Station_ID|      DATE|Element|Element_Value|MEASUREMENT_FLAG|QUALITY_FLAG|SOURCE_FLAG|OBSERVATION_TIME|
# +-----------+----------+-------+-------------+----------------+------------+-----------+----------------+
# |AE000041196|2023-01-01|   TMAX|          252|            null|        null|          S|            null|
# |AE000041196|2023-01-01|   TMIN|          149|            null|        null|          S|            null|
# |AE000041196|2023-01-01|   PRCP|            0|               D|        null|          S|            null|
# |AE000041196|2023-01-01|   TAVG|          207|               H|        null|          S|            null|
# |AEM00041194|2023-01-01|   TMAX|          255|            null|        null|          S|            null|
# |AEM00041194|2023-01-01|   TMIN|          186|            null|        null|          S|            null|
# |AEM00041194|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AEM00041194|2023-01-01|   TAVG|          223|               H|        null|          S|            null|
# |AEM00041217|2023-01-01|   TMAX|          248|            null|        null|          S|            null|
# |AEM00041217|2023-01-01|   TMIN|          184|            null|        null|          S|            null|
# |AEM00041217|2023-01-01|   TAVG|          215|               H|        null|          S|            null|
# |AEM00041218|2023-01-01|   TMAX|          254|            null|        null|          S|            null|
# |AEM00041218|2023-01-01|   TMIN|          145|            null|        null|          S|            null|
# |AEM00041218|2023-01-01|   TAVG|          193|               H|        null|          S|            null|
# |AG000060390|2023-01-01|   TMIN|           47|            null|        null|          S|            null|
# |AG000060390|2023-01-01|   TAVG|          128|               H|        null|          S|            null|
# |AG000060590|2023-01-01|   TAVG|          134|               H|        null|          S|            null|
# |AG000060611|2023-01-01|   TMIN|           24|            null|        null|          S|            null|
# |AG000060611|2023-01-01|   TAVG|          104|               H|        null|          S|            null|
# |AGE00147708|2023-01-01|   TMIN|           96|            null|        null|          S|            null|
# |AGE00147708|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGE00147708|2023-01-01|   TAVG|          155|               H|        null|          S|            null|
# |AGE00147716|2023-01-01|   TMAX|          193|            null|        null|          S|            null|
# |AGE00147716|2023-01-01|   TMIN|           76|            null|        null|          S|            null|
# |AGE00147716|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGE00147716|2023-01-01|   TAVG|          138|               H|        null|          S|            null|
# |AGE00147718|2023-01-01|   TMIN|           60|            null|        null|          S|            null|
# |AGE00147718|2023-01-01|   TAVG|          119|               H|        null|          S|            null|
# |AGE00147719|2023-01-01|   TMIN|            1|            null|        null|          S|            null|
# |AGE00147719|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGE00147719|2023-01-01|   TAVG|           74|               H|        null|          S|            null|
# |AGM00060351|2023-01-01|   TMAX|          201|            null|        null|          S|            null|
# |AGM00060351|2023-01-01|   TMIN|           82|            null|        null|          S|            null|
# |AGM00060351|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060351|2023-01-01|   TAVG|          137|               H|        null|          S|            null|
# |AGM00060355|2023-01-01|   TMAX|          234|            null|        null|          S|            null|
# |AGM00060355|2023-01-01|   TMIN|          126|            null|        null|          S|            null|
# |AGM00060355|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060355|2023-01-01|   TAVG|          178|               H|        null|          S|            null|
# |AGM00060360|2023-01-01|   TMIN|           75|            null|        null|          S|            null|
# |AGM00060360|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060360|2023-01-01|   TAVG|          132|               H|        null|          S|            null|
# |AGM00060402|2023-01-01|   TMIN|           98|            null|        null|          S|            null|
# |AGM00060402|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060402|2023-01-01|   TAVG|          149|               H|        null|          S|            null|
# |AGM00060403|2023-01-01|   TMAX|          241|            null|        null|          S|            null|
# |AGM00060403|2023-01-01|   TMIN|           37|            null|        null|          S|            null|
# |AGM00060403|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060403|2023-01-01|   TAVG|          137|               H|        null|          S|            null|
# |AGM00060419|2023-01-01|   TMIN|           14|            null|        null|          S|            null|
# |AGM00060419|2023-01-01|   TAVG|           91|               H|        null|          S|            null|
# |AGM00060421|2023-01-01|   TMIN|            2|            null|        null|          S|            null|
# |AGM00060421|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060421|2023-01-01|   TAVG|          110|               H|        null|          S|            null|
# |AGM00060423|2023-01-01|   TMIN|           66|            null|        null|          S|            null|
# |AGM00060423|2023-01-01|   TAVG|          136|               H|        null|          S|            null|
# |AGM00060425|2023-01-01|   TMAX|          222|            null|        null|          S|            null|
# |AGM00060425|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060425|2023-01-01|   TAVG|          158|               H|        null|          S|            null|
# |AGM00060430|2023-01-01|   TMIN|          101|            null|        null|          S|            null|
# |AGM00060430|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060430|2023-01-01|   TAVG|          148|               H|        null|          S|            null|
# |AGM00060437|2023-01-01|   TMIN|           87|            null|        null|          S|            null|
# |AGM00060437|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060437|2023-01-01|   TAVG|          129|               H|        null|          S|            null|
# |AGM00060444|2023-01-01|   TMIN|           49|            null|        null|          S|            null|
# |AGM00060444|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060444|2023-01-01|   TAVG|          110|               H|        null|          S|            null|
# |AGM00060445|2023-01-01|   TMIN|           20|            null|        null|          S|            null|
# |AGM00060445|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060445|2023-01-01|   TAVG|           71|               H|        null|          S|            null|
# |AGM00060452|2023-01-01|   TMIN|          104|            null|        null|          S|            null|
# |AGM00060452|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060452|2023-01-01|   TAVG|          158|               H|        null|          S|            null|
# |AGM00060457|2023-01-01|   TMIN|           51|            null|        null|          S|            null|
# |AGM00060457|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060457|2023-01-01|   TAVG|          152|               H|        null|          S|            null|
# |AGM00060461|2023-01-01|   TMAX|          186|            null|        null|          S|            null|
# |AGM00060461|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060461|2023-01-01|   TAVG|          155|               H|        null|          S|            null|
# |AGM00060467|2023-01-01|   TMAX|          167|            null|        null|          S|            null|
# |AGM00060467|2023-01-01|   TMIN|           19|            null|        null|          S|            null|
# |AGM00060467|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060467|2023-01-01|   TAVG|          103|               H|        null|          S|            null|
# |AGM00060468|2023-01-01|   TMAX|          182|            null|        null|          S|            null|
# |AGM00060468|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060468|2023-01-01|   TAVG|           68|               H|        null|          S|            null|
# |AGM00060475|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060475|2023-01-01|   TAVG|           84|               H|        null|          S|            null|
# |AGM00060490|2023-01-01|   TMIN|           36|            null|        null|          S|            null|
# |AGM00060490|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060490|2023-01-01|   TAVG|          115|               H|        null|          S|            null|
# |AGM00060507|2023-01-01|   TMAX|          214|            null|        null|          S|            null|
# |AGM00060507|2023-01-01|   TMIN|           70|            null|        null|          S|            null|
# |AGM00060507|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060507|2023-01-01|   TAVG|          143|               H|        null|          S|            null|
# |AGM00060511|2023-01-01|   TMAX|          170|            null|        null|          S|            null|
# |AGM00060511|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060511|2023-01-01|   TAVG|           67|               H|        null|          S|            null|
# |AGM00060514|2023-01-01|   TMIN|           -1|            null|        null|          S|            null|
# |AGM00060514|2023-01-01|   TAVG|           93|               H|        null|          S|            null|
# |AGM00060515|2023-01-01|   TMAX|          147|            null|        null|          S|            null|
# |AGM00060515|2023-01-01|   TMIN|           12|            null|        null|          S|            null|
# |AGM00060515|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060515|2023-01-01|   TAVG|           98|               H|        null|          S|            null|
# |AGM00060518|2023-01-01|   TMIN|          133|            null|        null|          S|            null|
# |AGM00060518|2023-01-01|   TAVG|          167|               H|        null|          S|            null|
# |AGM00060520|2023-01-01|   TMIN|           27|            null|        null|          S|            null|
# |AGM00060520|2023-01-01|   TAVG|          134|               H|        null|          S|            null|
# |AGM00060522|2023-01-01|   TMAX|          222|            null|        null|          S|            null|
# |AGM00060522|2023-01-01|   TMIN|           31|            null|        null|          S|            null|
# |AGM00060522|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060522|2023-01-01|   TAVG|          124|               H|        null|          S|            null|
# |AGM00060531|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060531|2023-01-01|   TAVG|          131|               H|        null|          S|            null|
# |AGM00060535|2023-01-01|   TMAX|          137|            null|        null|          S|            null|
# |AGM00060535|2023-01-01|   TMIN|            7|            null|        null|          S|            null|
# |AGM00060535|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060535|2023-01-01|   TAVG|           76|               H|        null|          S|            null|
# |AGM00060536|2023-01-01|   TMAX|          185|            null|        null|          S|            null|
# |AGM00060536|2023-01-01|   TMIN|           90|            null|        null|          S|            null|
# |AGM00060536|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060536|2023-01-01|   TAVG|          136|               H|        null|          S|            null|
# |AGM00060549|2023-01-01|   TMAX|          151|            null|        null|          S|            null|
# |AGM00060549|2023-01-01|   TMIN|           40|            null|        null|          S|            null|
# |AGM00060549|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060549|2023-01-01|   TAVG|           91|               H|        null|          S|            null|
# |AGM00060550|2023-01-01|   TMIN|           65|            null|        null|          S|            null|
# |AGM00060550|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060550|2023-01-01|   TAVG|           87|               H|        null|          S|            null|
# |AGM00060555|2023-01-01|   TMAX|          181|            null|        null|          S|            null|
# |AGM00060555|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060555|2023-01-01|   TAVG|           99|               H|        null|          S|            null|
# |AGM00060557|2023-01-01|   TMAX|          128|            null|        null|          S|            null|
# |AGM00060557|2023-01-01|   TMIN|           39|            null|        null|          S|            null|
# |AGM00060557|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060557|2023-01-01|   TAVG|           93|               H|        null|          S|            null|
# |AGM00060559|2023-01-01|   TMAX|          174|            null|        null|          S|            null|
# |AGM00060559|2023-01-01|   TMIN|           46|            null|        null|          S|            null|
# |AGM00060559|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060559|2023-01-01|   TAVG|          102|               H|        null|          S|            null|
# |AGM00060560|2023-01-01|   TMIN|           25|            null|        null|          S|            null|
# |AGM00060560|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060560|2023-01-01|   TAVG|          100|               H|        null|          S|            null|
# |AGM00060566|2023-01-01|   TMIN|           46|            null|        null|          S|            null|
# |AGM00060566|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060566|2023-01-01|   TAVG|          106|               H|        null|          S|            null|
# |AGM00060571|2023-01-01|   TMIN|           70|            null|        null|          S|            null|
# |AGM00060571|2023-01-01|   TAVG|          109|               H|        null|          S|            null|
# |AGM00060580|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060580|2023-01-01|   TAVG|          103|               H|        null|          S|            null|
# |AGM00060581|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060581|2023-01-01|   TAVG|          124|               H|        null|          S|            null|
# |AGM00060602|2023-01-01|   TMAX|          178|            null|        null|          S|            null|
# |AGM00060602|2023-01-01|   TMIN|           97|            null|        null|          S|            null|
# |AGM00060602|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060602|2023-01-01|   TAVG|          140|               H|        null|          S|            null|
# |AGM00060603|2023-01-01|   TMAX|          216|            null|        null|          S|            null|
# |AGM00060603|2023-01-01|   TMIN|           66|            null|        null|          S|            null|
# |AGM00060603|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060603|2023-01-01|   TAVG|          161|               H|        null|          S|            null|
# |AGM00060607|2023-01-01|   TMAX|          206|            null|        null|          S|            null|
# |AGM00060607|2023-01-01|   TMIN|           94|            null|        null|          S|            null|
# |AGM00060607|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060607|2023-01-01|   TAVG|          144|               H|        null|          S|            null|
# |AGM00060620|2023-01-01|   TAVG|          151|               H|        null|          S|            null|
# |AGM00060640|2023-01-01|   TMAX|          211|            null|        null|          S|            null|
# |AGM00060640|2023-01-01|   TMIN|           58|            null|        null|          S|            null|
# |AGM00060640|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060640|2023-01-01|   TAVG|          131|               H|        null|          S|            null|
# |AGM00060656|2023-01-01|   TMIN|           86|            null|        null|          S|            null|
# |AGM00060656|2023-01-01|   TAVG|          150|               H|        null|          S|            null|
# |AGM00060670|2023-01-01|   TAVG|          102|               H|        null|          S|            null|
# |AGM00060690|2023-01-01|   TMAX|          244|            null|        null|          S|            null|
# |AGM00060690|2023-01-01|   TMIN|          132|            null|        null|          S|            null|
# |AGM00060690|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AGM00060690|2023-01-01|   TAVG|          180|               H|        null|          S|            null|
# |AJ000037575|2023-01-01|   TMAX|          108|            null|        null|          S|            null|
# |AJ000037575|2023-01-01|   TMIN|          -17|            null|        null|          S|            null|
# |AJ000037575|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037575|2023-01-01|   TAVG|           33|               H|        null|          S|            null|
# |AJ000037675|2023-01-01|   TMAX|          118|            null|        null|          S|            null|
# |AJ000037675|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037675|2023-01-01|   TAVG|           56|               H|        null|          S|            null|
# |AJ000037735|2023-01-01|   TMAX|          117|            null|        null|          S|            null|
# |AJ000037735|2023-01-01|   TMIN|          -23|            null|        null|          S|            null|
# |AJ000037735|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037735|2023-01-01|   TAVG|           49|               H|        null|          S|            null|
# |AJ000037747|2023-01-01|   TAVG|           41|               H|        null|          S|            null|
# |AJ000037749|2023-01-01|   TMAX|          125|            null|        null|          S|            null|
# |AJ000037749|2023-01-01|   TMIN|           10|            null|        null|          S|            null|
# |AJ000037749|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037749|2023-01-01|   TAVG|           50|               H|        null|          S|            null|
# |AJ000037756|2023-01-01|   TMAX|          113|            null|        null|          S|            null|
# |AJ000037756|2023-01-01|   TMIN|          -37|            null|        null|          S|            null|
# |AJ000037756|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037756|2023-01-01|   TAVG|           33|               H|        null|          S|            null|
# |AJ000037907|2023-01-01|   TAVG|           38|               H|        null|          S|            null|
# |AJ000037985|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AJ000037985|2023-01-01|   TAVG|           44|               H|        null|          S|            null|
# |ALM00013615|2023-01-01|   TAVG|           89|               H|        null|          S|            null|
# |AM000037618|2023-01-01|   TMAX|           98|            null|        null|          S|            null|
# |AM000037618|2023-01-01|   TMIN|         -134|            null|        null|          S|            null|
# |AM000037618|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037618|2023-01-01|   TAVG|          -50|               H|        null|          S|            null|
# |AM000037682|2023-01-01|   TMAX|           31|            null|        null|          S|            null|
# |AM000037682|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037682|2023-01-01|   TAVG|          -35|               H|        null|          S|            null|
# |AM000037699|2023-01-01|   TMAX|           33|            null|        null|          S|            null|
# |AM000037699|2023-01-01|   TMIN|         -128|            null|        null|          S|            null|
# |AM000037699|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037699|2023-01-01|   TAVG|          -60|               H|        null|          S|            null|
# |AM000037704|2023-01-01|   TMAX|           94|            null|        null|          S|            null|
# |AM000037704|2023-01-01|   TMIN|         -106|            null|        null|          S|            null|
# |AM000037704|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037704|2023-01-01|   TAVG|          -26|               H|        null|          S|            null|
# |AM000037711|2023-01-01|   TMAX|          102|            null|        null|          S|            null|
# |AM000037711|2023-01-01|   TMIN|            9|            null|        null|          S|            null|
# |AM000037711|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037711|2023-01-01|   TAVG|           36|               H|        null|          S|            null|
# |AM000037787|2023-01-01|   TMAX|           65|            null|        null|          S|            null|
# |AM000037787|2023-01-01|   TMIN|         -105|            null|        null|          S|            null|
# |AM000037787|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037787|2023-01-01|   TAVG|          -31|               H|        null|          S|            null|
# |AM000037792|2023-01-01|   TMAX|           50|            null|        null|          S|            null|
# |AM000037792|2023-01-01|   TMIN|         -140|            null|        null|          S|            null|
# |AM000037792|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037792|2023-01-01|   TAVG|          -71|               H|        null|          S|            null|
# |AM000037801|2023-01-01|   TMAX|           35|            null|        null|          S|            null|
# |AM000037801|2023-01-01|   TMIN|         -145|            null|        null|          S|            null|
# |AM000037801|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037801|2023-01-01|   TAVG|          -74|               H|        null|          S|            null|
# |AM000037815|2023-01-01|   TMIN|         -130|            null|        null|          S|            null|
# |AM000037815|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037815|2023-01-01|   TAVG|          -46|               H|        null|          S|            null|
# |AM000037897|2023-01-01|   TMAX|           89|            null|        null|          S|            null|
# |AM000037897|2023-01-01|   TMIN|         -141|            null|        null|          S|            null|
# |AM000037897|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AM000037897|2023-01-01|   TAVG|          -54|               H|        null|          S|            null|
# |AM000037958|2023-01-01|   TMAX|           95|            null|        null|          S|            null|
# |AM000037958|2023-01-01|   TMIN|           -1|            null|        null|          S|            null|
# |AM000037958|2023-01-01|   TAVG|           40|               H|        null|          S|            null|
# |AMM00037717|2023-01-01|   TMAX|           32|            null|        null|          S|            null|
# |AMM00037717|2023-01-01|   TMIN|          -68|            null|        null|          S|            null|
# |AMM00037717|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AMM00037717|2023-01-01|   TAVG|          -27|               H|        null|          S|            null|
# |AO000066160|2023-01-01|   TAVG|          281|               H|        null|          S|            null|
# |AQC00914000|2023-01-01|   PRCP|            0|            null|        null|          7|            1000|
# |AQC00914141|2023-01-01|   PRCP|            0|            null|        null|          7|            null|
# |AQC00914594|2023-01-01|   PRCP|            0|            null|        null|          7|            null|
# |AQW00061705|2023-01-01|   TMAX|          300|            null|        null|          7|            2400|
# |AQW00061705|2023-01-01|   TMIN|          239|            null|        null|          7|            2400|
# |AQW00061705|2023-01-01|   PRCP|          577|            null|        null|          7|            2400|
# |AQW00061705|2023-01-01|   AWND|           45|            null|        null|          7|            null|
# |AR000000011|2023-01-01|   TMAX|          386|            null|        null|          S|            null|
# |AR000000011|2023-01-01|   TAVG|          286|               H|        null|          S|            null|
# |AR000087007|2023-01-01|   TMAX|          243|            null|        null|          S|            null|
# |AR000087007|2023-01-01|   TMIN|           65|            null|        null|          S|            null|
# |AR000087007|2023-01-01|   PRCP|            5|            null|        null|          S|            null|
# |AR000087007|2023-01-01|   TAVG|          143|               H|        null|          S|            null|
# |AR000087078|2023-01-01|   TMAX|          430|            null|        null|          S|            null|
# |AR000087078|2023-01-01|   TMIN|          278|            null|        null|          S|            null|
# |AR000087078|2023-01-01|   TAVG|          369|               H|        null|          S|            null|
# |AR000087129|2023-01-01|   TMAX|          417|            null|        null|          S|            null|
# |AR000087129|2023-01-01|   TMIN|          250|            null|        null|          S|            null|
# |AR000087129|2023-01-01|   TAVG|          345|               H|        null|          S|            null|
# |AR000087155|2023-01-01|   TAVG|          333|               H|        null|          S|            null|
# |AR000087217|2023-01-01|   TMAX|          371|            null|        null|          S|            null|
# |AR000087217|2023-01-01|   TMIN|          234|            null|        null|          S|            null|
# |AR000087217|2023-01-01|   TAVG|          280|               H|        null|          S|            null|
# |AR000087257|2023-01-01|   TMAX|          388|            null|        null|          S|            null|
# |AR000087257|2023-01-01|   TMIN|          214|            null|        null|          S|            null|
# |AR000087257|2023-01-01|   TAVG|          271|               H|        null|          S|            null|
# |AR000087270|2023-01-01|   TAVG|          294|               H|        null|          S|            null|
# |AR000087344|2023-01-01|   TMAX|          288|            null|        null|          S|            null|
# |AR000087344|2023-01-01|   TMIN|          184|            null|        null|          S|            null|
# |AR000087344|2023-01-01|   PRCP|          201|            null|        null|          S|            null|
# |AR000087344|2023-01-01|   TAVG|          222|               H|        null|          S|            null|
# |AR000087374|2023-01-01|   TMAX|          390|            null|        null|          S|            null|
# |AR000087374|2023-01-01|   PRCP|           20|            null|        null|          S|            null|
# |AR000087374|2023-01-01|   TAVG|          247|               H|        null|          S|            null|
# |AR000087418|2023-01-01|   TMAX|          316|            null|        null|          S|            null|
# |AR000087418|2023-01-01|   TMIN|          160|            null|        null|          S|            null|
# |AR000087418|2023-01-01|   TAVG|          242|               H|        null|          S|            null|
# |AR000087534|2023-01-01|   TMIN|          180|            null|        null|          S|            null|
# |AR000087534|2023-01-01|   PRCP|          279|            null|        null|          S|            null|
# |AR000087534|2023-01-01|   TAVG|          205|               H|        null|          S|            null|
# |AR000087623|2023-01-01|   TMAX|          358|            null|        null|          S|            null|
# |AR000087623|2023-01-01|   PRCP|          109|            null|        null|          S|            null|
# |AR000087623|2023-01-01|   TAVG|          211|               H|        null|          S|            null|
# |AR000087692|2023-01-01|   TAVG|          193|               H|        null|          S|            null|
# |AR000087715|2023-01-01|   TMAX|          375|            null|        null|          S|            null|
# |AR000087715|2023-01-01|   TMIN|          186|            null|        null|          S|            null|
# |AR000087715|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AR000087715|2023-01-01|   TAVG|          247|               H|        null|          S|            null|
# |AR000087803|2023-01-01|   TMAX|          255|            null|        null|          S|            null|
# |AR000087803|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AR000087803|2023-01-01|   TAVG|          119|               H|        null|          S|            null|
# |AR000087828|2023-01-01|   TMAX|          364|            null|        null|          S|            null|
# |AR000087828|2023-01-01|   TMIN|          187|            null|        null|          S|            null|
# |AR000087828|2023-01-01|   TAVG|          229|               H|        null|          S|            null|
# |AR000087860|2023-01-01|   TMAX|          316|            null|        null|          S|            null|
# |AR000087860|2023-01-01|   TMIN|          129|            null|        null|          S|            null|
# |AR000087860|2023-01-01|   TAVG|          203|               H|        null|          S|            null|
# |AR000087925|2023-01-01|   TMAX|          237|            null|        null|          S|            null|
# |AR000087925|2023-01-01|   TMIN|           68|            null|        null|          S|            null|
# |AR000087925|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |AR000087925|2023-01-01|   TAVG|          136|               H|        null|          S|            null|
# |AR000870470|2023-01-01|   TMIN|          162|            null|        null|          S|            null|
# |AR000870470|2023-01-01|   TAVG|          254|               H|        null|          S|            null|
# |AR000875440|2023-01-01|   TMAX|          338|            null|        null|          S|            null|
# |AR000875440|2023-01-01|   PRCP|          119|            null|        null|          S|            null|
# |AR000875440|2023-01-01|   TAVG|          196|               H|        null|          S|            null|
# |AR000875850|2023-01-01|   TMAX|          308|            null|        null|          S|            null|
# |AR000875850|2023-01-01|   TAVG|          232|               H|        null|          S|            null|
# |AR000877500|2023-01-01|   TMAX|          351|            null|        null|          S|            null|
# |AR000877500|2023-01-01|   PRCP|           10|            null|        null|          S|            null|
# |AR000877500|2023-01-01|   TAVG|          207|               H|        null|          S|            null|
# |ARM00087016|2023-01-01|   TMIN|          249|            null|        null|          S|            null|
# |ARM00087016|2023-01-01|   TAVG|          319|               H|        null|          S|            null|
# |ARM00087022|2023-01-01|   TMIN|          250|            null|        null|          S|            null|
# |ARM00087022|2023-01-01|   TAVG|          354|               H|        null|          S|            null|
# |ARM00087046|2023-01-01|   TMIN|          194|            null|        null|          S|            null|
# |ARM00087046|2023-01-01|   TAVG|          282|               H|        null|          S|            null|
# |ARM00087121|2023-01-01|   TMIN|          229|            null|        null|          S|            null|
# |ARM00087121|2023-01-01|   TAVG|          296|               H|        null|          S|            null|
# |ARM00087148|2023-01-01|   TMIN|          226|            null|        null|          S|            null|
# |ARM00087148|2023-01-01|   TAVG|          317|               H|        null|          S|            null|
# |ARM00087162|2023-01-01|   TMIN|          243|            null|        null|          S|            null|
# |ARM00087162|2023-01-01|   TAVG|          329|               H|        null|          S|            null|
# |ARM00087166|2023-01-01|   TMIN|          235|            null|        null|          S|            null|
# |ARM00087166|2023-01-01|   TAVG|          329|               H|        null|          S|            null|
# |ARM00087178|2023-01-01|   TMIN|          258|            null|        null|          S|            null|
# |ARM00087178|2023-01-01|   TAVG|          317|               H|        null|          S|            null|
# |ARM00087222|2023-01-01|   TMAX|          374|            null|        null|          S|            null|
# |ARM00087222|2023-01-01|   TMIN|          229|            null|        null|          S|            null|
# |ARM00087222|2023-01-01|   TAVG|          284|               H|        null|          S|            null|
# |ARM00087244|2023-01-01|   TMAX|          378|            null|        null|          S|            null|
# |ARM00087244|2023-01-01|   TMIN|          194|            null|        null|          S|            null|
# |ARM00087244|2023-01-01|   PRCP|          150|            null|        null|          S|            null|
# |ARM00087244|2023-01-01|   TAVG|          252|               H|        null|          S|            null|
# |ARM00087289|2023-01-01|   TMIN|          230|            null|        null|          S|            null|
# |ARM00087289|2023-01-01|   PRCP|            0|               D|        null|          S|            null|
# |ARM00087289|2023-01-01|   TAVG|          296|               H|        null|          S|            null|
# |ARM00087311|2023-01-01|   TMAX|          320|            null|        null|          S|            null|
# |ARM00087311|2023-01-01|   TMIN|          157|            null|        null|          S|            null|
# |ARM00087311|2023-01-01|   PRCP|           51|            null|        null|          S|            null|
# |ARM00087311|2023-01-01|   TAVG|          238|               H|        null|          S|            null|
# |ARM00087320|2023-01-01|   TMAX|          346|            null|        null|          S|            null|
# |ARM00087320|2023-01-01|   TMIN|          200|            null|        null|          S|            null|
# |ARM00087320|2023-01-01|   TAVG|          272|               H|        null|          S|            null|
# |ARM00087328|2023-01-01|   TMAX|          326|            null|        null|          S|            null|
# |ARM00087328|2023-01-01|   TMIN|          180|            null|        null|          S|            null|
# |ARM00087328|2023-01-01|   PRCP|          330|            null|        null|          S|            null|
# |ARM00087328|2023-01-01|   TAVG|          230|               H|        null|          S|            null|
# |ARM00087345|2023-01-01|   TMAX|          302|            null|        null|          S|            null|
# |ARM00087345|2023-01-01|   TMIN|          190|            null|        null|          S|            null|
# |ARM00087345|2023-01-01|   PRCP|          211|            null|        null|          S|            null|
# |ARM00087345|2023-01-01|   TAVG|          237|               H|        null|          S|            null|
# |ARM00087349|2023-01-01|   TMAX|          328|            null|        null|          S|            null|
# |ARM00087349|2023-01-01|   TMIN|          185|            null|        null|          S|            null|
# |ARM00087349|2023-01-01|   PRCP|          150|            null|        null|          S|            null|
# |ARM00087349|2023-01-01|   TAVG|          236|               H|        null|          S|            null|
# |ARM00087395|2023-01-01|   TMAX|          384|            null|        null|          S|            null|
# |ARM00087395|2023-01-01|   TAVG|          281|               H|        null|          S|            null|
# |ARM00087416|2023-01-01|   TMAX|          320|            null|        null|          S|            null|
# |ARM00087416|2023-01-01|   TMIN|          157|            null|        null|          S|            null|
# |ARM00087416|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |ARM00087416|2023-01-01|   TAVG|          236|               H|        null|          S|            null|
# |ARM00087420|2023-01-01|   TMAX|          302|            null|        null|          S|            null|
# |ARM00087420|2023-01-01|   TMIN|          150|            null|        null|          S|            null|
# |ARM00087420|2023-01-01|   PRCP|           10|            null|        null|          S|            null|
# |ARM00087420|2023-01-01|   TAVG|          242|               H|        null|          S|            null|
# |ARM00087436|2023-01-01|   TMAX|          327|            null|        null|          S|            null|
# |ARM00087436|2023-01-01|   TMIN|          162|            null|        null|          S|            null|
# |ARM00087436|2023-01-01|   PRCP|          300|            null|        null|          S|            null|
# |ARM00087436|2023-01-01|   TAVG|          207|               H|        null|          S|            null|
# |ARM00087448|2023-01-01|   TMAX|          330|            null|        null|          S|            null|
# |ARM00087448|2023-01-01|   TMIN|          157|            null|        null|          S|            null|
# |ARM00087448|2023-01-01|   PRCP|          551|            null|        null|          S|            null|
# |ARM00087448|2023-01-01|   TAVG|          203|               H|        null|          S|            null|
# |ARM00087453|2023-01-01|   TMAX|          325|            null|        null|          S|            null|
# |ARM00087453|2023-01-01|   TMIN|          172|            null|        null|          S|            null|
# |ARM00087453|2023-01-01|   PRCP|           81|               D|        null|          S|            null|
# |ARM00087453|2023-01-01|   TAVG|          207|               H|        null|          S|            null|
# |ARM00087467|2023-01-01|   TMAX|          350|            null|        null|          S|            null|
# |ARM00087467|2023-01-01|   PRCP|           30|            null|        null|          S|            null|
# |ARM00087467|2023-01-01|   TAVG|          228|               H|        null|          S|            null|
# |ARM00087480|2023-01-01|   TMAX|          381|            null|        null|          S|            null|
# |ARM00087480|2023-01-01|   TMIN|          193|            null|        null|          S|            null|
# |ARM00087480|2023-01-01|   PRCP|           10|            null|        null|          S|            null|
# |ARM00087480|2023-01-01|   TAVG|          234|               H|        null|          S|            null|
# |ARM00087497|2023-01-01|   TMAX|          378|            null|        null|          S|            null|
# |ARM00087497|2023-01-01|   TAVG|          237|               H|        null|          S|            null|
# |ARM00087506|2023-01-01|   TMAX|          259|            null|        null|          S|            null|
# |ARM00087506|2023-01-01|   TMIN|          124|            null|        null|          S|            null|
# |ARM00087506|2023-01-01|   PRCP|           61|            null|        null|          S|            null|
# |ARM00087506|2023-01-01|   TAVG|          190|               H|        null|          S|            null|
# |ARM00087509|2023-01-01|   TMAX|          290|            null|        null|          S|            null|
# |ARM00087509|2023-01-01|   TMIN|          128|            null|        null|          S|            null|
# |ARM00087509|2023-01-01|   PRCP|           51|            null|        null|          S|            null|
# |ARM00087509|2023-01-01|   TAVG|          206|               H|        null|          S|            null|
# |ARM00087532|2023-01-01|   TMAX|          343|            null|        null|          S|            null|
# |ARM00087532|2023-01-01|   PRCP|          351|            null|        null|          S|            null|
# |ARM00087532|2023-01-01|   TAVG|          196|               H|        null|          S|            null|
# |ARM00087548|2023-01-01|   TMAX|          366|            null|        null|          S|            null|
# |ARM00087548|2023-01-01|   TMIN|          178|            null|        null|          S|            null|
# |ARM00087548|2023-01-01|   PRCP|           89|            null|        null|          S|            null|
# |ARM00087548|2023-01-01|   TAVG|          209|               H|        null|          S|            null|
# |ARM00087576|2023-01-01|   TMAX|          336|            null|        null|          S|            null|
# |ARM00087576|2023-01-01|   TAVG|          220|               H|        null|          S|            null|
# |ARM00087582|2023-01-01|   TMAX|          286|            null|        null|          S|            null|
# |ARM00087582|2023-01-01|   PRCP|            0|               D|        null|          S|            null|
# |ARM00087582|2023-01-01|   TAVG|          228|               H|        null|          S|            null|
# |ARM00087593|2023-01-01|   TMAX|          296|            null|        null|          S|            null|
# |ARM00087593|2023-01-01|   TMIN|          200|            null|        null|          S|            null|
# |ARM00087593|2023-01-01|   TAVG|          219|               H|        null|          S|            null|
# |ARM00087596|2023-01-01|   TMIN|          195|            null|        null|          S|            null|
# |ARM00087596|2023-01-01|   TAVG|          236|               H|        null|          S|            null|
# |ARM00087640|2023-01-01|   TMAX|          326|            null|        null|          S|            null|
# |ARM00087640|2023-01-01|   TMIN|          165|            null|        null|          S|            null|
# |ARM00087640|2023-01-01|   PRCP|          140|            null|        null|          S|            null|
# |ARM00087640|2023-01-01|   TAVG|          186|               H|        null|          S|            null|
# |ARM00087641|2023-01-01|   TMAX|          310|            null|        null|          S|            null|
# |ARM00087641|2023-01-01|   TMIN|          145|            null|        null|          S|            null|
# |ARM00087641|2023-01-01|   PRCP|           20|            null|        null|          S|            null|
# |ARM00087641|2023-01-01|   TAVG|          172|               H|        null|          S|            null|
# |ARM00087643|2023-01-01|   TMAX|          303|            null|        null|          S|            null|
# |ARM00087643|2023-01-01|   TMIN|          151|            null|        null|          S|            null|
# |ARM00087643|2023-01-01|   PRCP|           10|            null|        null|          S|            null|
# |ARM00087643|2023-01-01|   TAVG|          178|               H|        null|          S|            null|
# |ARM00087645|2023-01-01|   TMAX|          277|            null|        null|          S|            null|
# |ARM00087645|2023-01-01|   TMIN|          135|            null|        null|          S|            null|
# |ARM00087645|2023-01-01|   TAVG|          166|               H|        null|          S|            null|
# |ARM00087648|2023-01-01|   TMAX|          277|            null|        null|          S|            null|
# |ARM00087648|2023-01-01|   TMIN|          151|            null|        null|          S|            null|
# |ARM00087648|2023-01-01|   TAVG|          199|               H|        null|          S|            null|
# |ARM00087679|2023-01-01|   TMAX|          333|            null|        null|          S|            null|
# |ARM00087679|2023-01-01|   PRCP|           71|            null|        null|          S|            null|
# |ARM00087679|2023-01-01|   TAVG|          169|               H|        null|          S|            null|
# |ARM00087765|2023-01-01|   TMAX|          263|            null|        null|          S|            null|
# |ARM00087765|2023-01-01|   TMIN|           95|            null|        null|          S|            null|
# |ARM00087765|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |ARM00087765|2023-01-01|   TAVG|          142|               H|        null|          S|            null|
# |ARM00087774|2023-01-01|   TMAX|          330|            null|        null|          S|            null|
# |ARM00087774|2023-01-01|   TMIN|          105|            null|        null|          S|            null|
# |ARM00087774|2023-01-01|   TAVG|          182|               H|        null|          S|            null|
# |ARM00087784|2023-01-01|   TMAX|          375|            null|        null|          S|            null|
# |ARM00087784|2023-01-01|   TMIN|          220|            null|        null|          S|            null|
# ...
# |ASN00009527|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009532|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009534|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009538|2023-01-01|   TMAX|          297|            null|        null|          a|            null|
# |ASN00009538|2023-01-01|   TMIN|          120|            null|        null|          a|            null|
# |ASN00009538|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009542|2023-01-01|   TMAX|          232|            null|        null|          a|            null|
# |ASN00009542|2023-01-01|   TMIN|          131|            null|        null|          a|            null|
# |ASN00009542|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009547|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009556|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009557|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009573|2023-01-01|   TMAX|          238|            null|        null|          a|            null|
# |ASN00009573|2023-01-01|   TMIN|          113|            null|        null|          a|            null|
# |ASN00009573|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009575|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009579|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009584|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009587|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009589|2023-01-01|   PRCP|            8|            null|        null|          a|            null|
# |ASN00009592|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009600|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009603|2023-01-01|   TMAX|          262|            null|        null|          a|            null|
# |ASN00009603|2023-01-01|   TMIN|           92|            null|        null|          a|            null|
# |ASN00009603|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009611|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009613|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009615|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009616|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009617|2023-01-01|   TMAX|          258|            null|        null|          a|            null|
# |ASN00009617|2023-01-01|   TMIN|           76|            null|        null|          a|            null|
# |ASN00009617|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009619|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009626|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009628|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009629|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009633|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009636|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009645|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009647|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009654|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009673|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009678|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009692|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009710|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009714|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009738|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009739|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009741|2023-01-01|   TMAX|          217|            null|        null|          S|            null|
# |ASN00009741|2023-01-01|   TMIN|          118|            null|        null|          S|            null|
# |ASN00009741|2023-01-01|   PRCP|            0|            null|        null|          S|            null|
# |ASN00009741|2023-01-01|   TAVG|          172|               H|        null|          S|            null|
# |ASN00009752|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009754|2023-01-01|   PRCP|            6|            null|        null|          a|            null|
# |ASN00009766|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009769|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009771|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009772|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009776|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009784|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009789|2023-01-01|   TMAX|          215|            null|        null|          a|            null|
# |ASN00009789|2023-01-01|   TMIN|          168|            null|        null|          a|            null|
# |ASN00009789|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009789|2023-01-01|   TAVG|          183|               H|        null|          S|            null|
# |ASN00009801|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009803|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009804|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009805|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009813|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009815|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009822|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009831|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009842|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009842|2023-01-01|   DATX|            2|            null|        null|          a|            null|
# |ASN00009842|2023-01-01|   MDTX|          280|            null|        null|          a|            null|
# |ASN00009850|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009852|2023-01-01|   PRCP|            6|            null|        null|          a|            null|
# |ASN00009868|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009871|2023-01-01|   TMAX|          210|            null|        null|          a|            null|
# |ASN00009871|2023-01-01|   DAPR|            2|            null|        null|          a|            null|
# |ASN00009871|2023-01-01|   DATN|            2|            null|        null|          a|            null|
# |ASN00009871|2023-01-01|   MDPR|            5|            null|        null|          a|            null|
# |ASN00009871|2023-01-01|   MDTN|          138|            null|        null|          a|            null|
# |ASN00009877|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009891|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009894|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009897|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009899|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009904|2023-01-01|   PRCP|            4|            null|        null|          a|            null|
# |ASN00009908|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009909|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009912|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009917|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009922|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009923|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009927|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009928|2023-01-01|   PRCP|            4|            null|        null|          a|            null|
# |ASN00009936|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009957|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009958|2023-01-01|   PRCP|            2|            null|        null|          a|            null|
# |ASN00009961|2023-01-01|   TMAX|          225|            null|        null|          a|            null|
# |ASN00009961|2023-01-01|   TMIN|          167|            null|        null|          a|            null|
# |ASN00009961|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009964|2023-01-01|   TMAX|          209|            null|        null|          a|            null|
# |ASN00009964|2023-01-01|   TMIN|          110|            null|        null|          a|            null|
# |ASN00009964|2023-01-01|   PRCP|            4|            null|        null|          a|            null|
# |ASN00009965|2023-01-01|   TMAX|          291|            null|        null|          a|            null|
# |ASN00009965|2023-01-01|   TMIN|          113|            null|        null|          a|            null|
# |ASN00009965|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009967|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009968|2023-01-01|   TMAX|          210|            null|        null|          a|            null|
# |ASN00009968|2023-01-01|   TMIN|          114|            null|        null|          a|            null|
# |ASN00009968|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009971|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009976|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009977|2023-01-01|   TMAX|          258|            null|        null|          a|            null|
# |ASN00009977|2023-01-01|   TMIN|          161|            null|        null|          a|            null|
# |ASN00009977|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009978|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009979|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009982|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009987|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009988|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009989|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009990|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009991|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009992|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009994|2023-01-01|   TMAX|          286|            null|        null|          a|            null|
# |ASN00009994|2023-01-01|   TMIN|           80|            null|        null|          a|            null|
# |ASN00009994|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009997|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00009998|2023-01-01|   TMAX|          210|            null|        null|          a|            null|
# |ASN00009998|2023-01-01|   TMIN|          129|            null|        null|          a|            null|
# |ASN00009998|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010000|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010007|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010007|2023-01-01|   DATX|            2|            null|        null|          a|            null|
# |ASN00010007|2023-01-01|   MDTX|          340|            null|        null|          a|            null|
# |ASN00010010|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010011|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010019|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010026|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010031|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010032|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010036|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010040|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010041|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010042|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# |ASN00010043|2023-01-01|   PRCP|            0|            null|        null|          a|            null|
# +-----------+----------+-------+-------------+----------------+------------+-----------+----------------+

# %% [markdown]
# Pr Q2 c

# %%
#Q2 c

#Bringing in the small directories 
states=(
    spark.read.text("hdfs:///data/ghcnd/ghcnd-states.txt"))

states=states.withColumn(
    'State_Code', F.substring('value', 1,2)).withColumn(
    'State_Name', F.substring('value', 4,47))

states=states.drop(F.col("value"))
#--------
countries=(
    spark.read.text("hdfs:///data/ghcnd/ghcnd-countries.txt"))

countries=countries.withColumn(
    'Country_Code', F.substring('value', 1,2)).withColumn(
    'Country_Name', F.substring('value', 4,60))

countries=countries.drop(F.col("value"))
#--------
inventory=(
    spark.read.text("hdfs:///data/ghcnd/ghcnd-inventory.txt"))

inventory=inventory.withColumn(
    'Station_ID', F.substring('value', 1,11)).withColumn(
    'Lat', F.substring('value', 13,8)).withColumn(
    'Lon', F.substring('value', 22,9)).withColumn(
    'Element', F.substring('value', 32,4)).withColumn(
    'First_Year', F.substring('value', 37,4)).withColumn(
    'Last_Year', F.substring('value', 42,4))

inventory=inventory.drop(F.col("value"))
#------
stations=(
    spark.read.text("hdfs:///data/ghcnd/ghcnd-stations.txt"))

stations=stations.withColumn(
    'Station_ID', F.substring('value', 1,11)).withColumn(
    'Lat', F.substring('value', 13,8)).withColumn(
    'Lon', F.substring('value', 22,9)).withColumn(
    'Elevation', F.substring('value', 32, 6)).withColumn(
    'State_Code', F.substring('value', 39,2)).withColumn(
    'Station_name', F.substring('value',42,30)).withColumn(
    'GSN_flag', F.substring('value', 73,3)).withColumn(
    'HCN_flag', F.substring('value',77,3)).withColumn(
    'WMO_ID', F.substring('value', 81,5))

stations=stations.drop(F.col("value"))

# %%
#also part of Q2c 
print("Inventory has "+f'{inventory.count()}'+" rows of data")
print("Countries has "+f'{countries.count()}'+" rows of data")
print("States has "+f'{states.count()}'+" rows of data")
print("Stations has "+f'{stations.count()}'+" rows of data")

wmo=(stations
     .select(
         F.count(F.when(
             (F.col("WMO_ID") =="     "), 1)).alias("# Stations without a WMO_id"),
         F.count(F.when(
             (F.col("WMO_ID") !="     "), 1)).alias("# Stations with a WMO_id")))
wmo.show()
# Out:
# Inventory has 737925 rows of data
# Countries has 219 rows of data
# States has 74 rows of data
# Stations has 124247 rows of data
# +---------------------------+------------------------+
# |# Stations without a WMO_id|# Stations with a WMO_id|
# +---------------------------+------------------------+
# |                     116288|                    7959|
# +---------------------------+------------------------+

# %% [markdown]
# ## Processing Q3

# %%
# !mkdir outputs

# %% [markdown]
# Pr Q3 a

# %%
#Q3 a
station_wCountry_Codes=stations.withColumn("Country_Code", stations.Station_ID.substr(1,2))

#Q3 b
station_and_countries=(station_wCountry_Codes
                       .join(countries, on="Country_Code", how="left"))
#Q3 c
station_country_states=(station_and_countries
                        .join(states, on='State_Code', how="left")
                        .na.fill(''))

# %% [markdown]
# Pr Q3 d

# %%
core_elements=["PRCP","SNOW","SNWD","TMAX","TMIN"]

# %%
#3 d
modified_inventory=(
    (inventory.drop(F.col("Lat")).drop(F.col("Lon"))
    .groupBy(["Station_ID"])
    .agg(
        F.collect_set("Element").alias("Station_Elements"),
        F.first("First_Year").alias("FirstYear"),
        F.last("Last_Year").alias("LastYear"),
        F.countDistinct("Element").alias("Element_Count")))
    .withColumn("Core_Element_Count", 
                F.size(F.array_intersect(
                    F.col("Station_Elements"), 
                    F.array([F.lit(w) for w in core_elements]))))
    .withColumn("Not_Core_Elements", 
                (F.col("Element_Count")-F.col("Core_Element_Count"))))

# %%
modified_inventory.show()
# Out:
# +-----------+--------------------+---------+--------+-------------+------------------+-----------------+
# | Station_ID|    Station_Elements|FirstYear|LastYear|Element_Count|Core_Element_Count|Not_Core_Elements|
# +-----------+--------------------+---------+--------+-------------+------------------+-----------------+
# |AGE00147719|[TMAX, TMIN, PRCP...|     1957|    2023|            4|                 3|                1|
# |ALE00100939|        [TMAX, PRCP]|     1940|    1990|            2|                 2|                0|
# |AQC00914873|[WT01, TMAX, TMIN...|     1955|    1959|           12|                 5|                7|
# |AR000000002|              [PRCP]|     1981|    2000|            1|                 1|                0|
# |AR000875850|[TMAX, TMIN, PRCP...|     1973|    2023|            5|                 4|                1|
# |ARM00087022|[TMAX, TMIN, PRCP...|     1977|    2023|            4|                 3|                1|
# |ARM00087480|[TMAX, TMIN, PRCP...|     1998|    2023|            5|                 4|                1|
# |ARM00087904|[TMAX, TMIN, PRCP...|     2003|    2023|            5|                 4|                1|
# |ASN00001003|              [PRCP]|     1909|    1940|            1|                 1|                0|
# |ASN00002033|              [PRCP]|     1920|    1965|            1|                 1|                0|
# |ASN00002042|[DWPR, PRCP, MDPR...|     1974|    1976|            4|                 1|                3|
# |ASN00003021|[DWPR, PRCP, MDPR...|     1954|    1962|            4|                 1|                3|
# |ASN00003047|              [PRCP]|     1929|    1940|            1|                 1|                0|
# |ASN00003069|[TMAX, DWPR, TMIN...|     1974|    1980|            6|                 3|                3|
# |ASN00004031|[DWPR, PRCP, MDPR...|     1975|    1983|            4|                 1|                3|
# |ASN00004047|[DWPR, PRCP, MDPR...|     1924|    1972|            4|                 1|                3|
# |ASN00004062|[DWPR, PRCP, MDPR...|     1916|    1927|            4|                 1|                3|
# |ASN00004087|              [PRCP]|     1984|    1986|            1|                 1|                0|
# |ASN00005004|[DWPR, PRCP, MDPR...|     1915|    2018|            4|                 1|                3|
# |ASN00006011|[MDTX, TMAX, MDTN...|     2017|    2023|           11|                 3|                8|
# +-----------+--------------------+---------+--------+-------------+------------------+-----------------+
# only showing top 20 rows

# %%
# Q3 d
# im pretty sure Hazel helped me with this prcp_only bit
prcp_only = lambda s: s=="PRCP"

q=(modified_inventory
   .select(
       F.count(F.when(
           (F.col("Core_Element_Count")=="5"),1))
       .alias("# stations collecting all 5 core element"),
       F.count(F.when((
           F.forall(F.col("Station_Elements"), prcp_only))
           ,1))
       .alias("# stations only collecting Precip"))
  )

q.show()
# Out:
# +----------------------------------------+---------------------------------+
# |# stations collecting all 5 core element|# stations only collecting Precip|
# +----------------------------------------+---------------------------------+
# |                                   20449|                            16272|
# +----------------------------------------+---------------------------------+

# %% [markdown]
# Pr Q3 e

# %%
# Q3 e
stations=(station_country_states.join(
    modified_inventory, on="Station_ID", how="left"))

# need to remove arrays to save as csv
stations_with_array_removed=(stations
                             .withColumn('Station_Elements', F.col('Station_Elements')
                                         .cast('string')))

# %%
def savefile(filename, tablename):

    name = "mda205"

    data_path = f"hdfs:///user/{name}/outputs/{filename}/"


    tablename.write.mode("overwrite").csv(data_path)
    
    (tablename.write
        .option("compression", "gzip")
        .mode("overwrite")
        .csv(data_path))

# %%
savefile("no_array_stations", stations_with_array_removed)

# %% [markdown]
# Pr Q3 f

# %%
# Q3 f
stations_with_dailyfirst1k=(
    stations
    .join(dailyfirst1k
          .withColumnRenamed("ID", "Station_ID"), 
          on="Station_ID", how="left"))

stations_with_dailyfirst1k.filter(F.col("Station_Name")=="").count()
# Out:
# 0

# %%
stations_broadcasted = F.broadcast(stations.withColumnRenamed("ID", "Station_ID")).cache()

# %%
# 3 f but not actually running - probably very expensive

# stations_daily=(
#     stations_broadcasted
#     .join(daily
#           .withColumnRenamed("ID", "Station_ID"), 
#           on="Station_ID", how="left"))

# %%
schema_stations = StructType([
    StructField("Station_ID", StringType(), True),
    StructField("State_Code", StringType(), True),
    StructField("Country_Code", StringType(), True),
    StructField("Lat", DoubleType(), True),
    StructField("Lon", DoubleType(), True),
    StructField("Elevation", IntegerType(), True),
    StructField("Station_Name", StringType(), True),
    StructField("GSN_flag", StringType(), True),
    StructField("HCN_flag", StringType(), True),
    StructField("WMO_ID", IntegerType(), True),
    StructField("Country_Name", StringType(), True),
    StructField("State_Name", StringType(), True),
    StructField("Station_Elements", StringType(), True),
    StructField("FirstYear", IntegerType(), True),
    StructField("LastYear", IntegerType(), True),
    StructField("Element_Count", IntegerType(), True),
    StructField("Core_Element_Count", IntegerType(), True),
    StructField("Not_Core_Elements", IntegerType(), True)
])

stations=(
    spark.read.format("com.databricks.spark.csv")
    .option("header", "False")
    .option("inferSchema", "False")
    .schema(schema_stations)
    .load("hdfs:///user/mda205/outputs/no_array_stations"))

# %%
stations.filter(F.col("Country_Code")=="EK").count()
# Out:
# 2

# %%
# Run this cell before closing the notebook or kill your spark application by hand using the link in the Spark UI

stop_spark()
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>mda205 (jupyter)</code> is under the completed applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li></ul>
